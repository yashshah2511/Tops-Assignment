# %%
# 1. Compute the minimum, 25th percentile, median, 75th, and maximum of ser. 

import pandas as pd
import numpy as np

# Example Series
ser = pd.Series(np.random.rand(100))  # 100 random numbers between 0 and 1

# Compute statistics
min_val = ser.min()
q1 = ser.quantile(0.25)
median = ser.median()
q3 = ser.quantile(0.75)
max_val = ser.max()

# Print results
print("Minimum:", min_val)
print("25th Percentile:", q1)
print("Median (50th Percentile):", median)
print("75th Percentile:", q3)
print("Maximum:", max_val)
# Out:
# Minimum: 0.005039888249548596
# 25th Percentile: 0.22745117659338593
# Median (50th Percentile): 0.4897887853495672
# 75th Percentile: 0.7292162750529909
# Maximum: 0.9901357034202254

# %%
# 2. Creating A Pandas Data Frame and Using Sample Data Sets 

import pandas as pd

# Creating a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris
# 3    David   40     Tokyo

# %%
# 3. Using NumPy, create a Pandas Data Frame with five rows and three columns. 

import numpy as np
import pandas as pd

# Create a 5x3 NumPy array with random integers (0–100)
data = np.random.randint(0, 101, size=(5, 3))

# Create DataFrame with column names
df = pd.DataFrame(data, columns=['Column_A', 'Column_B', 'Column_C'])

print(df)
# Out:
#    Column_A  Column_B  Column_C
# 0        34        82        38
# 1        84        15        35
# 2         0        89        23
# 3        19         7        14
# 4        31        50        91

# %%
# 4. For a Pandas Data Frame created from a NumPy array, what is the default behavior for the labels for the columns? For the rows? 

import numpy as np
import pandas as pd

# Create a 3x2 NumPy array
arr = np.array([[10, 20], [30, 40], [50, 60]])

# Create DataFrame without specifying labels
df = pd.DataFrame(arr)

print(df)
# Out:
#     0   1
# 0  10  20
# 1  30  40
# 2  50  60

# %%
# 5. take csv file contains at least 10,000 rows and 12 columns which numerical and text values according to that continue following steps. 

import pandas as pd

# Load the CSV file
df = pd.read_csv('C:\\TOPS\\tops-Assignment\\Tops-Assignment\\Assessment\\Data Collection, Cleaning, Visualization And Analysis\\Pandas\\audi.csv')  # Replace with the actual path to your file
df
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# [10668 rows x 9 columns]

# %%
# 6. Write the code to show the number of rows and columns in data frame. 

# Show number of rows and columns
rows, columns = df.shape
print("Number of Rows:", rows)
print("Number of Columns:", columns)
# Out:
# Number of Rows: 10668
# Number of Columns: 9

# %%
# 7. How might you show the first few rows of data frame? 


print(df.head(10))
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# 5    A1  2016  13900    Automatic    32260   Petrol   30  58.9         1.4
# 6    A6  2016  13250    Automatic    76788   Diesel   30  61.4         2.0
# 7    A4  2016  11750       Manual    75185   Diesel   20  70.6         2.0
# 8    A3  2015  10200       Manual    46112   Petrol   20  60.1         1.4
# 9    A1  2016  12000       Manual    22451   Petrol   30  55.4         1.4

# %%
# 8. If you select a single column from the diamonds Data Frame, what will be the type of the return value? 

import seaborn as sns

# Load the diamonds DataFrame
diamonds = sns.load_dataset("diamonds")
diamonds

# # Select a single column
carat_column = diamonds['carat']

# # Check the type
print(type(carat_column))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# 9. Create a line plot using the x and y values provided below. Label the y-axis as “Y” and
# label the x-axis as “X”.
# x = [3, 4, 5, 6]
# y = [1.5, 2, 2.5, 3] 

import matplotlib.pyplot as plt

# Data
x = [3, 4, 5, 6]
y = [1.5, 2, 2.5, 3]

# Create line plot
plt.plot(x, y, marker='o')  # 'o' adds markers on points

# Label the axes
plt.xlabel("X")
plt.ylabel("Y")

# Add a title (optional)
plt.title("Line Plot of X vs Y")

# Show the plot
plt.show()

# %%
# 10. Create an array of numbers between 0 and 6 with increments of 0.3 and name its “x”.
# Then on the same plot, plot x, x², x³, and x⁴. For consistency, use the following style lines
# respectively, “ro”, “bs”, “g”, and “:”. Lastly, make sure that the x-axis covers 0 to 6, while
# the y-axis spans from 0 to 125. Do not worry if you are not familiar with the style lines —
# you will recognize them as soon as you see the plot. 

import numpy as np
import matplotlib.pyplot as plt

# Create x values from 0 to 6 with 0.3 increments
x = np.arange(0, 6.1, 0.3)  # 6.1 to include 6

# Plot x vs x^1, x^2, x^3, x^4 with given styles
plt.plot(x, x, 'ro', label='x')         # red circles
plt.plot(x, x**2, 'bs', label='x^2')    # blue squares
plt.plot(x, x**3, 'g', label='x^3')     # green line
plt.plot(x, x**4, ':', label='x^4')     # dotted line

# Set axis limits
plt.xlim(0, 6)
plt.ylim(0, 125)

# Add labels and title
plt.xlabel("x")
plt.ylabel("y")
plt.title("x, x², x³, and x⁴ Plots")

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
# 11. Heights and initials of a group of individuals are provided below. Create a bar plot titled
# “Height Comparison” to compare the heights among this group.
# height = [179, 155, 191, 152, 188, 177]
# names = ['QA', 'WB', 'EC', 'RD', 'TE', 'YF'] 

import matplotlib.pyplot as plt

# Data
height = [179, 155, 191, 152, 188, 177]
names = ['QA', 'WB', 'EC', 'RD', 'TE', 'YF']

# Create bar plot
plt.bar(names, height, color='skyblue')

# Add title and axis labels
plt.title("Height Comparison")
plt.xlabel("Initials")
plt.ylabel("Height (cm)")

# Show the plot
plt.show()

# %%
# 12. Plot a histogram of x, where x consists of 100,000 randomly-selected points with a normal
# distribution (hint: you can use numpy.random.randn() to generate the random points). The
# histogram should have 10 bins. Look at how the histogram changes when we try 20 and 50
# bins. 

import numpy as np
import matplotlib.pyplot as plt

# Generate 100,000 random points with normal distribution (mean=0, std=1)
x = np.random.randn(100000)

# Plot histograms with different bin sizes
bin_sizes = [10, 20, 50]

for bins in bin_sizes:
    plt.figure(figsize=(8, 4))
    plt.hist(x, bins=bins, color='skyblue', edgecolor='black')
    plt.title(f'Histogram with {bins} Bins')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
# 13. What are the features of TensorFlow?

# %%
# 14. List a few limitations of TensorFlow.

# %%
# 15. What do you know about supervised and unsupervised machine learning?
